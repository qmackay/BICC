# %%
import pandas as pd

lc = '/Users/quinnmackay/Documents/GitHub/BICC/Holcene Revision Work/WD LC/Data Files/Original WD2014 Layer Count.tab'
load = pd.read_csv(lc, comment='#', names=['Depth', 'Age'], delim_whitespace=True, usecols=[0, 1])
load['Age'] = (load['Age'] * 1000)+50
load.to_csv('wd_lc.txt', index=False, sep='\t')
# Out:
# /var/folders/pq/tk8k94gn22v6mr07byx05hzc0000gn/T/ipykernel_7043/3795770306.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   load = pd.read_csv(lc, comment='#', names=['Depth', 'Age'], delim_whitespace=True, usecols=[0, 1])
