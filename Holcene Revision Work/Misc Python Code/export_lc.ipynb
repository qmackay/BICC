# %%
import pandas as pd

lc = '/Users/quinnmackay/Documents/GitHub/BICC/Holcene Revision Work/EDML LC/Data Files/EDML Layer Count.xlsx'
load = pd.read_excel(lc, names=['Depth', 'Count', 'Age'], usecols=[0, 1, 2], skiprows=1, sheet_name=1)
load.to_csv('edml_lc.txt', index=False, sep='\t')
