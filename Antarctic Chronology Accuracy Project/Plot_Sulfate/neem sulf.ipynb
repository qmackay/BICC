# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
#DEP

neem_dep = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/NEEM/NEEM DEP.txt', skiprows=110, comment='#', sep='\t', usecols=[0,1], names=['depth', 'dep']) 

neem_dep.dropna(inplace=True)
neem_dep.sort_values('depth', inplace=True)

neem_dep.to_csv('/Users/quinnmackay/Desktop/neem/neem_dep.txt', index=False)

# %%
#ECM

neem_ecm = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/NEEM/NEEM ECM.txt', skiprows=112, comment='#', sep='\t', usecols=[0,1], names=['depth', 'ecm']) 

neem_ecm.dropna(inplace=True)
neem_ecm.sort_values('depth', inplace=True)

neem_ecm.to_csv('/Users/quinnmackay/Desktop/neem/neem_ecm.txt', index=False)

# %%
#Sulfate

neem_sulfate = pd.read_excel('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/NEEM/NEEM Sulfate 10yr.xlsx', skiprows=18, usecols=[2,10], names=['depth', 'sulfate']) 

neem_sulfate.dropna(inplace=True)
neem_sulfate.sort_values('depth', inplace=True)


neem_sulfate.to_csv('/Users/quinnmackay/Desktop/neem/neem_sulfate.txt', index=False)
# Out:
# /opt/miniconda3/envs/bicc/lib/python3.13/site-packages/openpyxl/worksheet/_read_only.py:85: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
#Cond

neem_cond = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/NEEM/NEEM_mm_Cond.tab', skiprows=22, usecols=[0,1], sep='\t', names=['depth', 'cond']) 

neem_cond.dropna(inplace=True)
neem_cond.sort_values('depth', inplace=True)

neem_cond.to_csv('/Users/quinnmackay/Desktop/neem/neem_cond.txt', index=False)
