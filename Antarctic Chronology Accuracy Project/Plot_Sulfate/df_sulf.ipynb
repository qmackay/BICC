# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/DF/DF1 ECM.txt', sep='\t', header=None, skiprows=86)
shallow_df = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/DF/Shallow DF.txt', sep='\t', header=None, skiprows=86)

df1.columns = ['Depth', 'ecm']
shallow_df.columns = ['Depth', 'ecm']

full_df = pd.concat([df1, shallow_df], ignore_index=True)
full_df.sort_values('Depth', inplace=True)
full_df
# Out:
#           Depth    ecm
# 235141     6.20  0.989
# 235142     6.21  1.696
# 235143     6.22  3.172
# 235144     6.23  2.794
# 235145     6.24  4.270
# ...         ...    ...
# 235136  2503.03   4.02
# 235137  2503.04    4.1
# 235138  2503.05   3.89
# 235139  2503.06   3.89
# 235140  2503.07   3.94
#
# [244715 rows x 2 columns]

# %%
full_df.to_csv('/Users/quinnmackay/Desktop/df_shallow1.txt', index=False)
