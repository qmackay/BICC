# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
#ECM

edml_dc_ecm = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/EDML/EDML ECM.txt', comment='#', sep='\t', header=0, names=['depth', 'dc_ecm']) 

edml_dc_ecm.dropna(inplace=True)
edml_dc_ecm.sort_values('depth', inplace=True)

edml_dc_ecm.to_csv('/Users/quinnmackay/Desktop/edml/edml_dc_ecm.txt', index=False)

# %%
#Sulfate

edml_sulfate = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/EDML/EDML Sulfate_copied.txt', sep=r'\s+', skiprows=74, header=1, usecols=[1,7], names=['depth', 'sulfate']) 

edml_sulfate.dropna(inplace=True)
edml_sulfate.sort_values('depth', inplace=True)

edml_sulfate

edml_sulfate.to_csv('/Users/quinnmackay/Desktop/edml/edml_sulfate.txt', index=False)

# %%
#CFA Conductivity

edml_cfa_cond1 = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/EDML/EDML_CFA_113-1443.499m_1mm_resolution.txt', comment='#', sep='\t', header=0, usecols=[0,5], names=['depth', 'cond']) 
edml_cfa_cond2 = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/EDML/EDML_CFA_1443.5-2774m_1mm_resolution.txt', comment='#', sep='\t', header=0, usecols=[0,5], names=['depth', 'cond']) 

edml_cfa_cond1.dropna(inplace=True)
edml_cfa_cond1.sort_values('depth', inplace=True)

edml_cfa_cond2.dropna(inplace=True)
edml_cfa_cond2.sort_values('depth', inplace=True)

edml_cfa_cond = pd.concat([edml_cfa_cond1, edml_cfa_cond2], ignore_index=True)
edml_cfa_cond.sort_values('depth', inplace=True)
edml_cfa_cond.to_csv('/Users/quinnmackay/Desktop/edml/edml_cfa_cond.txt', index=False)
