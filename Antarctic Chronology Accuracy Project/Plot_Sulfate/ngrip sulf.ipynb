# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
#NG1 and NG2 ECM

ng1_ecm = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/NG/NG1_NG2 ECM.txt', skiprows=117, comment='#', sep='\t', usecols=[0,1], names=['depth', 'ecm']) 
ng2_ecm = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/NG/NG1_NG2 ECM.txt', skiprows=117, comment='#', sep='\t', usecols=[0,2], names=['depth', 'ecm']) 

ng1_ecm.dropna(inplace=True)
ng1_ecm.sort_values('depth', inplace=True)

ng2_ecm.dropna(inplace=True)
ng2_ecm.sort_values('depth', inplace=True)

ng1_ecm = ng1_ecm[ng1_ecm['ecm']>-0.5]
ng2_ecm = ng2_ecm[ng2_ecm['ecm']>-0.5]

ng1_ecm.to_csv('/Users/quinnmackay/Desktop/ngrip1/ng1_ecm.txt', index=False)
ng2_ecm.to_csv('/Users/quinnmackay/Desktop/ngrip2/ng2_ecm.txt', index=False)

# %%
#NG2 DEP

ng2_dep = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/NG/NGRIP DEP.txt', sep='\t', names=['depth', 'dep'], comment='#', skiprows=108)

ng2_dep.dropna(inplace=True)
ng2_dep.sort_values('depth', inplace=True)

ng2_dep.drop_duplicates(inplace=True)

ng2_dep.to_csv('/Users/quinnmackay/Desktop/ngrip2/ng2_dep.txt', index=False)

ng2_dep
# Out:
#            depth       dep
# 0       1298.705  0.000015
# 120001  1298.710  0.000014
# 2       1298.715  0.000014
# 3       1298.720  0.000014
# 4       1298.725  0.000014
# ...          ...       ...
# 363558  2930.305  0.000012
# 363559  2930.310  0.000012
# 363560  2930.315  0.000012
# 363561  2930.320  0.000012
# 363562  2930.325  0.000012
#
# [243563 rows x 2 columns]

# %%
#NG2 sulfate

ng2_sulfate = pd.read_excel('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/NG/NGRIP_Sulfate_60-9ka.xlsx', usecols=[1,2], names=['depth', 'sulfate'], skiprows=22)

ng2_sulfate.dropna(inplace=True)
ng2_sulfate.sort_values('depth', inplace=True)

ng2_sulfate.to_csv('/Users/quinnmackay/Desktop/ngrip2/ng2_sulfate.txt', index=False)
