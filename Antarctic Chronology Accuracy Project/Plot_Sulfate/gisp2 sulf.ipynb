# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
#Sulfate

gisp2_sulfate = pd.read_excel('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/GISP2/GISP2 Sulfate.xls', skiprows=37, usecols=[0,9], names=['depth', 'sulfate']) 

gisp2_sulfate.dropna(inplace=True)
gisp2_sulfate.sort_values('depth', inplace=True)

gisp2_sulfate.to_csv('/Users/quinnmackay/Desktop/gisp2/gisp2_sulfate.txt', index=False)

# %%
#ECM

gisp2_ecm = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/GISP2/GISP2 ECM.txt', skiprows=37, usecols=[0,1], sep='\t', names=['depth', 'ecm']) 

gisp2_ecm.dropna(inplace=True)
gisp2_ecm.sort_values('depth', inplace=True)

gisp2_ecm.to_csv('/Users/quinnmackay/Desktop/gisp2/gisp2_ecm.txt', index=False)
