# %%
from pathlib import Path
import pandas as pd
import numpy as np
import os

# %%
#Sulfate

td_sulfate = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/TALDICE/Mirko Sulfate.txt', comment='#', encoding='latin-1', sep=r'\s+', header=0, usecols=[0,1], names=['depth', 'sulfate']) 

td_sulfate.dropna(inplace=True)
td_sulfate.sort_values('depth', inplace=True)

file_name = 'td_sulfate.txt'
core = 'td'

#create dir if necessary
output_dir = f'/Users/quinnmackay/Documents/GitHub/BICC/Antarctic Chronology Accuracy Project/Plot_Sulfate/out/{core}'
os.makedirs(output_dir, exist_ok=True)

# save file
td_sulfate.to_csv(f'{output_dir}/{file_name}', index=False)
