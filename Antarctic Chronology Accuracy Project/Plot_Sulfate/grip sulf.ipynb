# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
#ECM

grip_ecm = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/GRIP/GRIP ECM.tab', skiprows=17, sep='\t', usecols=[0,1], names=['depth', 'ecm']) 

grip_ecm.dropna(inplace=True)
grip_ecm.sort_values('depth', inplace=True)

grip_ecm.to_csv('/Users/quinnmackay/Desktop/grip/grip_ecm.txt', index=False)

# %%
#DEP & ECM2

grip_dep = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/GRIP/GRIP_DEP.tab', skiprows=78, sep='\t', usecols=[0,1], names=['depth', 'dep']) 

grip_ecm2 = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/GRIP/GRIP_DEP.tab', skiprows=78, sep='\t', usecols=[0,2], names=['depth', 'ecm2']) 

grip_dep.dropna(inplace=True)
grip_dep.sort_values('depth', inplace=True)

grip_ecm2.dropna(inplace=True)
grip_ecm2.sort_values('depth', inplace=True)

grip_dep.to_csv('/Users/quinnmackay/Desktop/grip/grip_dep.txt', index=False)

grip_ecm2.to_csv('/Users/quinnmackay/Desktop/grip/grip_ecm2.txt', index=False)

# %%
#DEP2

grip_dep2 = pd.DataFrame()

for i in range(1,11):
    grip_dep2_temp = pd.read_csv(f'/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/Specific Sulfate/GRIP/DEP/dep{i}.dat.txt', skiprows=0, sep='\t', usecols=[0,1], names=['depth', 'dep']) 
    grip_dep2 = pd.concat([grip_dep2, grip_dep2_temp], ignore_index=True)

grip_dep2.dropna(inplace=True)
grip_dep2.sort_values('depth', inplace=True)

grip_dep2.to_csv('/Users/quinnmackay/Desktop/grip/grip_dep2.txt', index=False)
