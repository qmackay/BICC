# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

edc_so4 = pd.read_excel('/Users/quinnmackay/Downloads/EDC_FIC_sulfate_7_3190m.xlsx', sheet_name=1, usecols=[0,1], names=['depth', 'so4'])

# %%
edc_so4
# Out:
#            depth     so4
# 0          6.926   74.11
# 1          6.990   91.01
# 2          7.054  105.40
# 3          7.118   83.54
# 4          7.194   82.74
# ...          ...     ...
# 143058  3189.920  173.70
# 143059  3189.930  174.84
# 143060  3189.950  215.98
# 143061  3189.970  252.59
# 143062  3189.990  246.98
#
# [143063 rows x 2 columns]

# %%
plt.plot(edc_so4['depth'], edc_so4['so4'])
plt.xlabel('Depth (m)')
plt.ylabel('Sulfate Concentration (ppb)')

plt.xlim(463.3, 463.8)
plt.ylim(0, 400)
# Out:
# (0.0, 400.0)
