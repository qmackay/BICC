# %%
import pandas as pd
import numpy as np

depo_dir = '/Users/quinnmackay/Documents/GitHub/paleochrono/BICC2025/NGRIP/temp/deposition.txt'

depo = pd.read_csv(depo_dir, delimiter='\t')

# %%
depo['rel_unc'] = np.ones(len(depo['depth'])) * 0.2

depo.to_csv('/Users/quinnmackay/Documents/GitHub/paleochrono/BICC2025/NGRIP/temp/depo_fixed.txt', sep='\t', index=False)

# %%
depo
# Out:
#       depth  deporate  rel_unc
# 0         8    0.1797      0.2
# 1         9    0.1710      0.2
# 2        10    0.1796      0.2
# 3        11    0.2011      0.2
# 4        12    0.1733      0.2
# ...     ...       ...      ...
# 3070   3078    0.2138      0.2
# 3071   3079    0.2141      0.2
# 3072   3080    0.2144      0.2
# 3073   3081    0.2136      0.2
# 3074   3082    0.2141      0.2
#
# [3075 rows x 3 columns]
