# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_15N = pd.read_excel('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/DF/DF CH4, TAC, d15N-N2.xlsx', sheet_name=6, skiprows=18, usecols=[0,1], names=['depth', 'd15n'])

# %%
R = 8.314462
T = -60 + 273.15
g = 9.80665
delta_m = 0.000997

step_1 = (R * T) / (delta_m * g) 
step_2 = np.log(1+(df_15N['d15n']/1000))

DCH = step_1 * step_2
Convec_zone = 2 #guess

df_15N['LID'] = DCH + Convec_zone

# %%
df_15N.plot(x='depth', y='LID', kind='line', color='k', marker='o', ms=3, mfc='red')
# Out:
# <Axes: xlabel='depth'>
