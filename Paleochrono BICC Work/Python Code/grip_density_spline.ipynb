# %%
#importing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline
from scipy.optimize import curve_fit
import os

os.chdir('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/')

ngrip_merged_density = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Paleochrono BICC Work/Paleochrono BICC Experiment/BICC2025/NGRIP/density.txt', sep='\t')
grip_existing_density = pd.read_csv('/Users/quinnmackay/Documents/GitHub/BICC/Data Storage/GRIP/GRIP1991shallow_density.txt', sep=',', comment = '#', header=None, skiprows=6, names=['depth', 'density'])
grip_existing_density['rel_dens'] = grip_existing_density['density'] / 921

print(grip_existing_density)

plt.plot(ngrip_merged_density['depth'], ngrip_merged_density['rel_dens'], label='NGRIP Merged Density')
plt.scatter(grip_existing_density['depth'], grip_existing_density['rel_dens'], label='GRIP Existing Density', s = 5, color='red')

plt.xlim(0,200)
# Out:
#     depth  density  rel_dens
# 0    6.53    434.2  0.471444
# 1    7.77    453.8  0.492725
# 2    9.00    468.6  0.508795
# 3   10.20    487.3  0.529099
# 4   11.27    503.3  0.546471
# ..    ...      ...       ...
# 68  78.54    825.2  0.895983
# 69  79.49    816.0  0.885993
# 70  80.50    841.4  0.913572
# 71  81.32    836.3  0.908035
# 72  82.29    827.5  0.898480
#
# [73 rows x 3 columns]
# (0.0, 200.0)
