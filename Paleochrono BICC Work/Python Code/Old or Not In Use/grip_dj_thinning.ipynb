# %%
#importing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline
from scipy.optimize import curve_fit
import os

# %%
#dj calculation, doesn't seem to work well
acc = 0.15
H = 3029
h = int((0.2*H)+1)

# H-h
a_top = []
for z in range(h+1,H+1):
    a1 = (2*(H-h))/(2*acc)
    a2 = np.log((2*H-h)/((2*z)-h))
    a_top.append(a1*a2)

a_prime = ((2*H-h)/(2*acc))*np.log(((2*H)-h)/(h))

a_bottom = []
for z in range(0+1,h):
    a3 = a_prime + (((2*H)-h)/acc)
    a4 = (h/z) - 1
    a_bottom.append(a3*a4)

a_bottom
# Out:
# [np.float64(46143892.00414357),
#  np.float64(23033810.554134477),
#  np.float64(15330450.070798112),
#  np.float64(11478769.82912993),
#  np.float64(9167761.68412902),
#  np.float64(7627089.587461747),
#  np.float64(6526609.5184136955),
#  np.float64(5701249.4666276565),
#  np.float64(5059302.759682959),
#  np.float64(4545745.394127201),
#  np.float64(4125562.095036127),
#  np.float64(3775409.3457935653),
#  np.float64(3479126.250280628),
#  np.float64(3225169.311269539),
#  np.float64(3005073.2974599283),
#  np.float64(2812489.2853765194),
#  np.float64(2642562.2158911587),
#  np.float64(2491515.9319041707),
#  np.float64(2356369.2567579187),
#  np.float64(2234737.2491262923),
#  np.float64(2124689.2422214868),
#  np.float64(2024645.599580755),
#  np.float64(1933301.4041261736),
#  np.float64(1849569.2249594738),
#  np.float64(1772535.62012611),
#  np.float64(1701427.6772030052),
#  np.float64(1635586.9893112413),
#  np.float64(1574449.2076974607),
# ...
