# %%
import pandas as pd

thinning_dir = '/Users/quinnmackay/Documents/GitHub/paleochrono/BICC2025/NGRIP/temp/thinning.txt'

thinning = pd.read_csv(thinning_dir, delimiter='\t')

# %%
thinning['rel_unc'] = thinning['thinning'] * 0.02

thinning.to_csv('/Users/quinnmackay/Documents/GitHub/paleochrono/BICC2025/NGRIP/temp/thinning_fixed.txt', sep='\t', index=False)

# %%
thinning
# Out:
#       depth  thinning   rel_unc
# 0         8    0.9955  0.019910
# 1         9    0.9953  0.019906
# 2        10    0.9951  0.019902
# 3        11    0.9948  0.019896
# 4        12    0.9946  0.019892
# ...     ...       ...       ...
# 3070   3078    0.0669  0.001338
# 3071   3079    0.0669  0.001338
# 3072   3080    0.0668  0.001336
# 3073   3081    0.0668  0.001336
# 3074   3082    0.0667  0.001334
#
# [3075 rows x 3 columns]
