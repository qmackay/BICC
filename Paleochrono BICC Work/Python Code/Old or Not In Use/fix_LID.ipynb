# %%
import pandas as pd
import numpy as np

lid_dir = '/Users/quinnmackay/Documents/GitHub/paleochrono/BICC2025/NGRIP/temp/lock_in_depth.txt'

val = pd.read_csv(lid_dir, delimiter='\t')

# %%
val['rel_unc'] = np.ones(len(val['depth'])) * 0.2

val.to_csv('/Users/quinnmackay/Documents/GitHub/paleochrono/BICC2025/NGRIP/temp/lid_fixed.txt', sep='\t', index=False)

# %%
val
# Out:
#       depth    LID  rel_unc
# 0        21  26.77      0.2
# 1        22  27.57      0.2
# 2        23  28.15      0.2
# 3        24  28.93      0.2
# 4        25  29.49      0.2
# ...     ...    ...      ...
# 3057   3078  46.02      0.2
# 3058   3079  46.01      0.2
# 3059   3080  46.00      0.2
# 3060   3081  45.99      0.2
# 3061   3082  45.98      0.2
#
# [3062 rows x 3 columns]
